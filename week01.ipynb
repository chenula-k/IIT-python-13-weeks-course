# %% [markdown]
# # IIT python class

# %% [markdown]
# # week 01 homework

# %% [markdown]
# very first command-print

# %%
print("Hello Sri lanka")
# Out:
# Hello Sri lanka

# %%
Print("IIT World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Print("IIT World")
#
# NameError: name 'Print' is not defined

# %% [markdown]
# NameError = "print" is the correct one

# %%
print('hi srilanka')
# Out:
# hi srilanka

# %% [markdown]
# # My Bio

# %%
print("My name is chenula,")
print("I am an A level student,")
print("Im currently learning the python programming language.")
# Out:
# My name is chenula,
# I am an A level student,
# Im currently learning the python programming language.
