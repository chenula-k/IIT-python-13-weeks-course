# %% [markdown]
# # Variable Declaration and verification

# %%
x=10
y="Sri lanka"
z=75.80
print(x)
print(y)
print(z)
# Out:
# 10
# Sri lanka
# 75.8

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
print(type(z))
# Out:
# <class 'float'>
