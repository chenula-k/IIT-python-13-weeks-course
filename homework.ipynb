# %%
name=input("Enter your name")
marks=int(input("Enter your marks"))
if marks>80:
          print("A")
elif marks>=60:
          print("B")
elif marks>=40:
          print("C")
else:
    print("fail")
# Out:
# Enter your name gh
# Enter your marks 56
# C
